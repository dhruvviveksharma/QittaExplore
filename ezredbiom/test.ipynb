# %%
import openai, os
client = openai.OpenAI(base_url="https://ellm.nrp-nautilus.io/v1", 
api_key="SQEQakZU9TIOoAzdVYA0pKu9NcrgWBbx")
stream = client.chat.completions.create(
    model="qwen3",
    messages=[{"role":"user","content":"What is 2+2?"}],
    stream=True,
    extra_body={"enable_thinking": True},
)
for chunk in stream:
    d = chunk.choices[0].delta
    r = getattr(d, "reasoning_content", None)
    c = getattr(d, "content", None)
    if r: print("THINK:", r, end="", flush=True)
    if c: print("TOKEN:", c, end="", flush=True)
print()
# Out:
# TOKEN:
#
# TOKEN: 2TOKEN:  +TOKEN:  TOKEN: 2TOKEN:  equalsTOKEN:  **TOKEN: 4TOKEN: **.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 11
#       4 stream = client.chat.completions.create(
#       5     model="qwen3",
#       6     messages=[{"role":"user","content":"What is 2+2?"}],
#       7     stream=True,
#       8     extra_body={"enable_thinking": True},
#       9 )
#      10 for chunk in stream:
# ---> 11     d = chunk.choices[0].delta
#      12     r = getattr(d, "reasoning_content", None)
#      13     c = getattr(d, "content", None)
#
# IndexError: list index out of range
